# %% [markdown]
# ## Unicorn Companies Dataset
# A list of all the current Unicorn Companies in the world
# https://www.kaggle.com/datasets/deepcontractor/unicorn-companies-dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px #importing plotless express for quick visualizations
import plotly.graph_objects as go #importing graph objects
import plotly.figure_factory as ff #importing figure factory

# %%
df = pd.read_csv('Unicorn_Companies.csv')
pd.set_option('display.max_columns', None) #expanding hidden columns
df.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140    4/7/2017          China        Beijing
# 1      SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2      Stripe            $95   1/23/2014  United States  San Francisco
# 3      Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games            $42  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
df.shape
# Out:
# (1037, 16)

# %% [markdown]
# Loaded the Sri Lanka economy data set to give perspective of a unicorn company

# %%
df.describe()
# Out:
#        Company Valuation ($B) Date Joined        Country           City  \
# count     1037           1037        1037           1037           1037
# unique    1035            200         623             46            256
# top       Bolt             $1   7/13/2021  United States  San Francisco
# freq         2            244           9            536            145
#
#        Industry Select Inverstors Founded Year Total Raised Financial Stage  \
# count      1037              1037         1037         1037            1037
# unique       33              1006           37          914              10
# top     Fintech              None         2015         None            None
# freq        205                17          144           24             988
#
#        Investors Count Deal Terms Portfolio Exits
# count             1037       1037            1037
# unique              54         16               5
# top                 10          1            None
# ...

# %%
unique_values = df.apply(lambda x: x.unique()) # Checking the unique values for each column
print(unique_values)
# Out:
# Company              [Bytedance, SpaceX, Stripe, Klarna, Epic Games...
# Valuation ($B)       [$140, $100.3, $95, $45.6, $42, $40, $39, $38,...
# Date Joined          [4/7/2017, 12/1/2012, 1/23/2014, 12/12/2011, 1...
# Country              [China, United States, Sweden, Australia, Unit...
# City                 [Beijing, Hawthorne, San Francisco, Stockholm,...
# Industry             [Artificial intelligence, Other, Fintech, Inte...
# Select Inverstors    [Sequoia Capital China, SIG Asia Investments, ...
# Founded Year         [2012, 2002, 2010, 2005, 1991, 2013, 2015, 201...
# Total Raised         [$7.44B, $6.874B, $2.901B, $3.472B, $4.377B, $...
# Financial Stage      [IPO, None, Asset, Acquired, Acq, Divestiture,...
# Investors Count      [28, 29, 39, 56, 25, 26, 15, 31, 40, 21, 24, 4...
# Deal Terms           [8, 12, 13, 5, 4, 6, 3, 10, 9, 19, 1, 7, 2, 11...
# Portfolio Exits                                     [5, None, 1, 2, 3]
# dtype: object

# %%
df.dtypes #checking if the data types are in order
# Out:
# Company              object
# Valuation ($B)       object
# Date Joined          object
# Country              object
# City                 object
# Industry             object
# Select Inverstors    object
# Founded Year         object
# Total Raised         object
# Financial Stage      object
# Investors Count      object
# Deal Terms           object
# Portfolio Exits      object
# dtype: object

# %%
ind_shifted = df[df["Select Inverstors"] == "None"].index.to_list()
df.iloc[ind_shifted, :]
# Out:
#                          Company Valuation ($B) Date Joined    Country  \
# 10                           FTX            $32   7/20/2021    Bahamas
# 217                    HyalRoute           $3.5   5/26/2020  Singapore
# 292                  Amber Group             $3   6/21/2021  Hong Kong
# 318                       Moglix           $2.6   5/17/2021  Singapore
# 438   Advance Intelligence Group             $2   9/23/2021  Singapore
# 639                         Trax           $1.3   7/22/2019  Singapore
# 757                    Carousell           $1.1   9/15/2021  Singapore
# 789             LinkSure Network             $1    1/1/2015      China
# 814                        WeLab             $1   11/8/2017  Hong Kong
# 882                      PatSnap             $1   3/16/2021  Singapore
# 911                   Matrixport          $1.05    6/1/2021  Singapore
# 916                        Carro             $1   6/14/2021  Singapore
# ...

# %%
ind_shifted.remove(789)
for i, row in df.iterrows():
    if i in ind_shifted:
        city, industry, invest = df.at[i, "City"], df.at[i, "Industry"], df.at[i, "Select Inverstors"]
        df.at[i, "City"] = invest
        df.at[i, "Industry"] = city
        df.at[i, "Select Inverstors"] = industry

# %%
# remove the $ symbol from "Valuation ($B)" and convert "Date Joined" to datetime

df["Valuation ($B)"] = df["Valuation ($B)"].apply(lambda x: x[1:]).astype(float)
df["Date Joined"] = pd.to_datetime(df["Date Joined"])

# %%
# fill "None" values with np.nan

def replace_none_with_npnan(x):
    return np.nan if x == "None" else x

df = df.applymap(replace_none_with_npnan)
df["Investors Count"] = df["Investors Count"].fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1037 non-null   object
#  1   Valuation ($B)     1037 non-null   float64
#  2   Date Joined        1037 non-null   datetime64[ns]
#  3   Country            1037 non-null   object
#  4   City               1021 non-null   object
#  5   Industry           1037 non-null   object
#  6   Select Inverstors  1036 non-null   object
#  7   Founded Year       994 non-null    object
#  8   Total Raised       1013 non-null   object
#  9   Financial Stage    49 non-null     object
#  10  Investors Count    1037 non-null   object
#  11  Deal Terms         1008 non-null   object
#  12  Portfolio Exits    49 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(11)
# memory usage: 105.4+ KB

# %%
# Get the actual values of "Total Raised" and replace the wrong values in data

def get_actual_total_raised(value: str) -> float:
    to_replace = "$BMK"
    unity = value[-1]
    value = float(''.join(v for v in value if v not in to_replace))
    if unity == "B":
        result = value * 1000000000
    elif unity == "M":
        result = value * 1000000
    elif unity == "K":
        result = value * 1000
    else:
        result = value
    return result
   
df["Total Raised"] = df["Total Raised"].apply(lambda x: get_actual_total_raised(x) if x is not np.nan else x)
df["Total Raised"] = df["Total Raised"] / 1e6
df = df.rename(columns={"Total Raised" : "Total Raised(M)", 
                        "Select Inverstors" : "Select Investors"})

df['Financial Stage'] = df['Financial Stage'].replace({"Acq" : "Acquired"})
df["Industry"] = df["Industry"].replace({"Finttech" : "Fintech", 
                                         "Artificial intelligence" : "Artificial Intelligence"})
df.head(7)
# Out:
#         Company  Valuation ($B) Date Joined         Country           City  \
# 0     Bytedance           140.0  2017-04-07           China        Beijing
# 1        SpaceX           100.3  2012-12-01   United States      Hawthorne
# 2        Stripe            95.0  2014-01-23   United States  San Francisco
# 3        Klarna            45.6  2011-12-12          Sweden      Stockholm
# 4    Epic Games            42.0  2018-10-26   United States           Cary
# 5         Canva            40.0  2018-01-08       Australia    Surry Hills
# 6  Checkout.com            40.0  2019-05-02  United Kingdom         London
#
#                        Industry  \
# 0       Artificial Intelligence
# 1                         Other
# 2                       Fintech
# 3                       Fintech
# 4                         Other
# 5  Internet software & services
# 6                       Fintech
#
#                                     Select Investors Founded Year  \
# ...

# %%
# change column types

#df["Country"] = df["Country"].astype('category')
#df["City"] = df["City"].astype('category')
#df["Industry"] = df["Industry"].astype('category')
#df["Investors Count"] = df["Investors Count"].astype(int)

# %%
df['Year'] = pd.DatetimeIndex(df['Date Joined']).year

# %%
df['Month'] = pd.DatetimeIndex(df['Date Joined']).month

# %%
import calendar
df['Month'] = df['Month'].apply(lambda x: calendar.month_abbr[x])

# %%
df['Date Joined'] = pd.to_datetime(df['Date Joined'])

# Extract the month from the 'Date Joined' column and store it in a new column 'Month'
df['Month Number'] = df['Date Joined'].dt.month

# Display the dataframe
print(df)
# Out:
#            Company  Valuation ($B) Date Joined        Country           City  \
# 0        Bytedance           140.0  2017-04-07          China        Beijing
# 1           SpaceX           100.3  2012-12-01  United States      Hawthorne
# 2           Stripe            95.0  2014-01-23  United States  San Francisco
# 3           Klarna            45.6  2011-12-12         Sweden      Stockholm
# 4       Epic Games            42.0  2018-10-26  United States           Cary
# ...            ...             ...         ...            ...            ...
# 1032     Timescale             1.0  2022-02-22  United States       New York
# 1033      Scalapay             1.0  2022-02-23          Italy          Milan
# 1034  Omada Health             1.0  2022-02-23  United States  San Francisco
# 1035    BlueVoyant             1.0  2022-02-23  United States       New York
# 1036          Veev             1.0  2022-02-24  United States      San Mateo
#
#                           Industry  \
# ...

# %%
df.fillna(0, inplace=True)

# %%
df.head()
# Out:
#       Company  Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           140.0  2017-04-07          China        Beijing
# 1      SpaceX           100.3  2012-12-01  United States      Hawthorne
# 2      Stripe            95.0  2014-01-23  United States  San Francisco
# 3      Klarna            45.6  2011-12-12         Sweden      Stockholm
# 4  Epic Games            42.0  2018-10-26  United States           Cary
#
#                   Industry                                   Select Investors  \
# 0  Artificial Intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
df.dtypes
# Out:
# Company                     object
# Valuation ($B)             float64
# Date Joined         datetime64[ns]
# Country                     object
# City                        object
# Industry                    object
# Select Investors            object
# Founded Year                object
# Total Raised(M)            float64
# Financial Stage             object
# Investors Count             object
# Deal Terms                  object
# Portfolio Exits             object
# Year                         int64
# Month                       object
# Month Number                 int64
# dtype: object

# %%
df['Founded Year'] = df['Founded Year'].astype(int)
df['Investors Count'] = df['Investors Count'].astype(int)
df['Deal Terms'] = df['Deal Terms'].astype(int)
df['Portfolio Exits'] = df['Portfolio Exits'].astype(int)

# %%
year_count = df.groupby('Year')['Month'].count()
year_count = pd.DataFrame(year_count)
year_count
# Out:
#       Month
# Year
# 2007      1
# 2011      2
# 2012      4
# 2013      3
# 2014     13
# 2015     35
# 2016     21
# 2017     44
# 2018    103
# 2019    107
# 2020    107
# 2021    514
# 2022     83

# %%
df.min()
# Out:
# C:\Users\Rohan Perera\AppData\Local\Temp\ipykernel_8164\3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# Company                         1047 Games
# Valuation ($B)                         1.0
# Date Joined            2007-07-20 00:00:00
# Country                          Argentina
# Industry           Artificial Intelligence
# Founded Year                             0
# Total Raised(M)                        0.0
# Investors Count                          0
# Deal Terms                               0
# Portfolio Exits                          0
# Year                                  2007
# Month                                  Apr
# Month Number                             1
# dtype: object

# %%
df.loc[df['Year']==1990]
# Out:
# Empty DataFrame
# Columns: [Company, Valuation ($B), Date Joined, Country, City, Industry, Select Investors, Founded Year, Total Raised(M), Financial Stage, Investors Count, Deal Terms, Portfolio Exits, Year, Month, Month Number]
# Index: []

# %%
df.count()
# Out:
# Company             1037
# Valuation ($B)      1037
# Date Joined         1037
# Country             1037
# City                1037
# Industry            1037
# Select Investors    1037
# Founded Year        1037
# Total Raised(M)     1037
# Financial Stage     1037
# Investors Count     1037
# Deal Terms          1037
# Portfolio Exits     1037
# Year                1037
# Month               1037
# Month Number        1037
# dtype: int64

# %%
sns.lineplot(data=year_count, x = "Year", y = "Month", )
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Month'>

# %%
df
# Out:
#            Company  Valuation ($B) Date Joined        Country           City  \
# 0        Bytedance           140.0  2017-04-07          China        Beijing
# 1           SpaceX           100.3  2012-12-01  United States      Hawthorne
# 2           Stripe            95.0  2014-01-23  United States  San Francisco
# 3           Klarna            45.6  2011-12-12         Sweden      Stockholm
# 4       Epic Games            42.0  2018-10-26  United States           Cary
# ...            ...             ...         ...            ...            ...
# 1032     Timescale             1.0  2022-02-22  United States       New York
# 1033      Scalapay             1.0  2022-02-23          Italy          Milan
# 1034  Omada Health             1.0  2022-02-23  United States  San Francisco
# 1035    BlueVoyant             1.0  2022-02-23  United States       New York
# 1036          Veev             1.0  2022-02-24  United States      San Mateo
#
#                           Industry  \
# ...

# %%
sns.barplot(data=df, x = "Year", y = "Total Raised(M)")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Raised(M)'>

# %%
pivot_table = df.pivot_table(values='Company', index='Year', aggfunc='count')
pivot_table
# Out:
#       Company
# Year
# 2007        1
# 2011        2
# 2012        4
# 2013        3
# 2014       13
# 2015       35
# 2016       21
# 2017       44
# 2018      103
# 2019      107
# 2020      107
# 2021      514
# 2022       83

# %%
valuation = df.pivot_table(values='Total Raised(M)', index='Year', aggfunc='sum')
pivot_table
# Out:
#       Company
# Year
# 2007        1
# 2011        2
# 2012        4
# 2013        3
# 2014       13
# 2015       35
# 2016       21
# 2017       44
# 2018      103
# 2019      107
# 2020      107
# 2021      514
# 2022       83

# %%
# Create a line chart showing the growth year on year
sns.lineplot(x="Year", y="Company", data=pivot_table, linewidth = 4)

# Add a title to the plot
plt.title("Year on Year Growth for Unicorn Companies")

# Display the plot
plt.show()

# %%
sns.set_theme(style='white')
sns.set(style='whitegrid', rc={'figure.figsize':(11.7,8.27)})
sns.axes_style("whitegrid")
sns.set_style("whitegrid", {'grid.color': 'gray'})

# %%
test = df.fillna(0, inplace=True)
print(test)
# Out:
# None

# %%
test

# %%
df.head()
# Out:
#       Company  Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           140.0  2017-04-07          China        Beijing
# 1      SpaceX           100.3  2012-12-01  United States      Hawthorne
# 2      Stripe            95.0  2014-01-23  United States  San Francisco
# 3      Klarna            45.6  2011-12-12         Sweden      Stockholm
# 4  Epic Games            42.0  2018-10-26  United States           Cary
#
#                   Industry                                   Select Investors  \
# 0  Artificial Intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
df.isna().count()
# Out:
# Company             1037
# Valuation ($B)      1037
# Date Joined         1037
# Country             1037
# City                1037
# Industry            1037
# Select Investors    1037
# Founded Year        1037
# Total Raised(M)     1037
# Financial Stage     1037
# Investors Count     1037
# Deal Terms          1037
# Portfolio Exits     1037
# Year                1037
# Month               1037
# Month Number        1037
# dtype: int64

# %%
fig = px.scatter(df, x = 'Year', y = 'Valuation ($B)', size= 'Total Raised(M)', color= 'Industry')
fig.show()
